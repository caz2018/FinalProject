# %%
import matplotlib.pyplot as plt
import datetime as dt
import fxcmpy

# %load_ext autoreload
# %autoreload 2

# %%
con = fxcmpy.fxcmpy(config_file='fxcm.cfg') 
# must optain API Token, see link for details.

start = dt.datetime(2018, 7, 6,8,0,0)
end = dt.datetime(2018, 7, 7,18,0,0)

c = con.get_candles('XAU/USD', period='m1', columns=['bidclose','tickqty'], start=start, end=end )

# %%
# Basic plotting of close and volumne data

fig, ax = plt.subplots(figsize=(11,8))
ax.plot(c.index,c['bidclose'], lw=1, color='B',label="Close")
ax2= ax.twinx()
ax2.plot(c.index,c['tickqty'], lw=1, color='G',label="Volume")
# plot.show()

# %%
start = dt.datetime(2018, 7, 2, 8, 0, 0)
end = dt.datetime(2018, 7, 18, 18, 0, 0)

c = con.get_candles('GBP/USD', period='D1', columns=['bidclose','tickqty'], start=start, end=end )
c
# Out:
#                      bidclose  tickqty
# date
# 2018-07-03 21:00:00   1.31891   323376
# 2018-07-04 21:00:00   1.32261   244795
# 2018-07-05 21:00:00   1.32202   361828
# 2018-07-06 21:00:00   1.32853   285534
# 2018-07-08 21:00:00   1.33174     1145
# 2018-07-09 21:00:00   1.32557   401436
# 2018-07-10 21:00:00   1.32735   322147
# 2018-07-11 21:00:00   1.32027   382639
# 2018-07-12 21:00:00   1.32040   306598
# 2018-07-13 21:00:00   1.32331   326216
# 2018-07-15 21:00:00   1.32267      160
# 2018-07-16 21:00:00   1.32342   255206
# 2018-07-17 21:00:00   1.31141   349594
# 2018-07-18 21:00:00   1.30684   332745

# %%
start = dt.datetime(2013, 6, 9, 23, 59, 0)
end = dt.datetime(2018, 7, 18, 23, 59, 0)

c = con.get_candles('GBP/USD', period='D1', columns=['bidclose','tickqty'], start=start, end=end )
c
# Out:
#                      bidclose  tickqty
# date
# 2013-06-11 21:00:00   1.56451   109370
# 2013-06-12 21:00:00   1.56765    87703
# 2013-06-13 21:00:00   1.57186   104153
# 2013-06-14 21:00:00   1.56981    87824
# 2013-06-16 21:00:00   1.57283      202
# 2013-06-17 21:00:00   1.57204    63908
# 2013-06-18 21:00:00   1.56428    76649
# 2013-06-19 21:00:00   1.54844    85587
# 2013-06-20 21:00:00   1.55076   121610
# 2013-06-21 21:00:00   1.54170   101013
# 2013-06-23 21:00:00   1.53723       64
# 2013-06-24 21:00:00   1.54341    96801
# 2013-06-25 21:00:00   1.54216    94808
# 2013-06-26 21:00:00   1.53133    89550
# 2013-06-27 21:00:00   1.52585    81734
# 2013-06-28 21:00:00   1.52081    85288
# 2013-06-30 21:00:00   1.51994       57
# 2013-07-01 21:00:00   1.52147    66763
# 2013-07-02 21:00:00   1.51538    72046
# 2013-07-03 21:00:00   1.52776    85596
# 2013-07-04 21:00:00   1.50689    82989
# 2013-07-05 21:00:00   1.48831    95763
# 2013-07-07 21:00:00   1.48708      113
# 2013-07-08 21:00:00   1.49498    62069
# 2013-07-09 21:00:00   1.48652    82484
# 2013-07-10 21:00:00   1.50075    91907
# 2013-07-11 21:00:00   1.51811   141563
# 2013-07-12 21:00:00   1.50982    81317
# 2013-07-15 21:00:00   1.50987    74808
# 2013-07-16 21:00:00   1.51582    93564
# ...                       ...      ...
# 2018-06-15 21:00:00   1.32747   384693
# 2018-06-17 21:00:00   1.32607       33
# 2018-06-18 21:00:00   1.32449   272705
# 2018-06-19 21:00:00   1.31728   389566
# 2018-06-20 21:00:00   1.31681   323814
# 2018-06-21 21:00:00   1.32375   448890
# 2018-06-22 21:00:00   1.32577   359040
# 2018-06-24 21:00:00   1.32497       79
# 2018-06-25 21:00:00   1.32758   306036
# 2018-06-26 21:00:00   1.32177   325850
# 2018-06-27 21:00:00   1.31106   392751
# 2018-06-28 21:00:00   1.30762   419832
# 2018-06-29 21:00:00   1.32028   445965
# 2018-07-01 21:00:00   1.31827      620
# 2018-07-02 21:00:00   1.31418   334830
# 2018-07-03 21:00:00   1.31891   323376
# 2018-07-04 21:00:00   1.32261   244795
# 2018-07-05 21:00:00   1.32202   361828
# 2018-07-06 21:00:00   1.32853   285534
# 2018-07-08 21:00:00   1.33174     1145
# 2018-07-09 21:00:00   1.32557   401436
# 2018-07-10 21:00:00   1.32735   322147
# 2018-07-11 21:00:00   1.32027   382639
# 2018-07-12 21:00:00   1.32040   306598
# 2018-07-13 21:00:00   1.32331   326216
# 2018-07-15 21:00:00   1.32267      160
# 2018-07-16 21:00:00   1.32342   255206
# 2018-07-17 21:00:00   1.31141   349594
# 2018-07-18 21:00:00   1.30684   332745
# 2018-07-19 21:00:00   1.30137   400912
#
# [1580 rows x 2 columns]

# %%
c.to_csv("daily_csv.csv")
